# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory </span>
# ## <span style="color:brown"> Python Exercise 11 </span>
# ## <span style="color:orange"> Keras - Neural Network regression </span>

# %% [markdown]
# ### Overview
#
# In this notebook our task will be to perform machine learning regression on noisy data with a Neural Network (NN).
#
# We will explore how the ability to fit depends on the structure of the NN. The goal is also to build intuition about why prediction is difficult.

# %% [markdown]
# ### The Prediction Problem
#
# Consider a probabilistic process that gives rise to labeled data $(x,y)$. The data is generated by drawing samples from the equation
#
# $$
#     y_i= f(x_i) + \eta_i,
# $$
#
# where $f(x_i)$ is some fixed, but (possibly unknown) function, and $\eta_i$ is a Gaussian, uncorrelate noise variable such that
#
# $$
# \langle \eta_i \rangle=0 \\
# \langle \eta_i \eta_j \rangle = \delta_{ij} \sigma
# $$
#
# We will refer to the $f(x_i)$ as the **true features** used to generate the data.
#
# To make predictions, we will consider a NN that depends on its parameters, weights and biases. The functions that the NN can model respresent the **model class** that we are using to try to model the data and make predictions.
#
# To learn the parameters of the NN, we will train our models on a **training data set** and then test the effectiveness of the NN on a *different* dataset, the **validation data set**. The reason we must divide our data into a training and test dataset is that the point of machine learning is to make accurate predictions about new data we have not seen.
#
# To measure our ability to predict, we will learn our parameters by fitting our training dataset and then making predictions on our test data set. One common measure of predictive  performance of our algorithm is to compare the predictions,$\{y_j^\mathrm{pred}\}$, to the true values $\{y_j\}$. A commonly employed measure for this is the sum of the mean square-error (MSE) on the test set:
# $$
# MSE= \frac{1}{N_\mathrm{test}}\sum_{j=1}^{N_\mathrm{test}} (y_j^\mathrm{pred}-y_j)^2
# $$
#
# We will try to get a qualitative picture by examining plots on validation and training data.

# %% [markdown]
# ### Linear fit
#
# We start by considering the very simple case:
# $$
# f(x)=2x+1
# $$

# %% [markdown]
# Let's start defining the parameters of an ideal linear function which we are going to predict through a neural network regression

# %%
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# %% [markdown]
# Now let's generate a set of input data which will slightly deviate from our ideal behaviour using a random noise (that actually is set to zero):

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 500)
x_valid = np.random.uniform(-1, 1, 50)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0.0 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# %%
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target, label='target')
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# If you remember how a single node of a neural network works, you can easily spot that **just a single neuron can make the job**. So let's start using a simple Sequential model with just one layer on one neuron only!

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
# Out:
# 2023-06-01 10:25:28.357259: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-01 10:25:28.406539: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-01 10:25:28.670635: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-01 10:25:28.671997: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We are now going to train our model, that is we feed the neuron with the set of training pair x, y_train from which the optimizer will find the best weights to minimize the Mean Square Error loss function (out linear regression function).

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=30,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/30
# 16/16 [==============================] - 0s 10ms/step - loss: 0.9265 - mse: 0.9265 - val_loss: 0.6239 - val_mse: 0.6239
# Epoch 2/30
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5376 - mse: 0.5376 - val_loss: 0.3636 - val_mse: 0.3636
# Epoch 3/30
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3229 - mse: 0.3229 - val_loss: 0.2207 - val_mse: 0.2207
# Epoch 4/30
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2020 - mse: 0.2020 - val_loss: 0.1403 - val_mse: 0.1403
# Epoch 5/30
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1320 - mse: 0.1320 - val_loss: 0.0935 - val_mse: 0.0935
# Epoch 6/30
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0901 - mse: 0.0901 - val_loss: 0.0657 - val_mse: 0.0657
# Epoch 7/30
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0643 - mse: 0.0643 - val_loss: 0.0479 - val_mse: 0.0479
# Epoch 8/30
# ...

# %% [markdown]
# By looking at weights and biases we can see if the linear fit was successfull: $w_1$ represents the angular coefficient, $b$ the intercept.

# %%
# return weights and biases
model.get_weights()
# Out:
# [array([[1.9708996]], dtype=float32), array([0.9997692], dtype=float32)]

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 2.6948e-04 - mse: 2.6948e-04
#
# Test loss: 0.0002694847935345024
# Test accuracy: 0.0002694847935345024

# %%
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 2.6948e-04 - mse: 2.6948e-04
#
# Test loss: 0.0002694847935345024
# Test accuracy: 0.0002694847935345024

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()
# Out:
# 4/4 [==============================] - 0s 1ms/step

# %% [markdown]
# ### Exercise 11.1
#
# In order to make practice with NN, explore how does the previous linear regression depend on the number of epochs, $N_{\mathrm{epochs}}$, the number of data points $N_{\mathrm{train}}$ and on the noise $\sigma$. Try to improve the previous result operating on these parameters.

# %% [markdown]
# ### Results
# Incresing $N_{\mathrm{train}}$ proved to be the most effective change. Going from $N_{\mathrm{epochs}}=30$ to $N_{\mathrm{epochs}}=50$, and doubling the $N_{\mathrm{train}}$ results in a much better fit.
# Incresing the $\sigma$ appears to be counter productive due to the semplicity of our neural network, since there really is no risk of overfittig. While increasing the number of inputs can counteract the adverse effects of adding a sigma, there is no reason to do so.

# %%
# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 1000)
x_valid = np.random.uniform(-1, 1, 100)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0.0 # noise standard deviation, kept it 0
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# plot validation and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target, label='target')
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
newmod = tf.keras.Sequential()
newmod.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
newmod.compile(optimizer='sgd', loss='mse', metrics=['mse'])
# get a summary of our composed model
newmod.summary()

bsize = 32

history = newmod.fit(x=x_train, y=y_train, 
          batch_size=bsize, epochs=50,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Model: "sequential_43"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_148 (Dense)           (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6510 - mse: 0.6510 - val_loss: 0.3280 - val_mse: 0.3280
# Epoch 2/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2078 - mse: 0.2078 - val_loss: 0.1139 - val_mse: 0.1139
# Epoch 3/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0757 - mse: 0.0757 - val_loss: 0.0476 - val_mse: 0.0476
# Epoch 4/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0239 - val_mse: 0.0239
# Epoch 5/50
# ...

# %%
# return weights and biases
print('Old weights: ', model.get_weights())
print('New weights: ', newmod.get_weights())
# Out:
# Old weights:  [array([[1.9708996]], dtype=float32), array([0.9997692], dtype=float32)]
# New weights:  [array([[1.9999905]], dtype=float32), array([0.9999999], dtype=float32)]

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=bsize, verbose=0)
nscore = newmod.evaluate(x_valid, y_valid, batch_size=bsize, verbose=0)
# print performance
print('Evaluating model')
print('Test loss:', nscore[0], '               Old test loss ', score[0])
print('Test accuracy:', nscore[1],'           Old test accuracy ', score[1] )

# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=bsize, verbose=0)
nscore = newmod.evaluate(x_valid, y_target, batch_size=bsize, verbose=0)
# print performance
print('Evaluating model with exact curve')
print('Test loss:', nscore[0], '               Old test loss ', score[0])
print('Test accuracy:', nscore[1],'           Old test accuracy ', score[1] )
# Out:
# Evaluating model
# Test loss: 3.524958450129567e-11                Old test loss  0.00032802499481476843
# Test accuracy: 3.524958450129567e-11            Old test accuracy  0.00032802499481476843
# Evaluating model with exact curve
# Test loss: 3.524958450129567e-11                Old test loss  0.00032802499481476843
# Test accuracy: 3.524958450129567e-11            Old test accuracy  0.00032802499481476843

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = newmod.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()
# Out:
# 4/4 [==============================] - 0s 1ms/step

# %% [markdown]
# ### Exercise 11.2
#
# Try to extend the model to obtain a reasonable fit of the following polynomial of order 3:
#
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
# for $x \in [-1,1]$.
#
# Find good (& reasonable) choices for:
#
# - the number of layers
# - the number of neurons in each layer
# - the activation function
# - the optimizer
# - the loss function
#
# Check your NN model by seeing how well your fits predict newly generated test data (including on data outside the range you fit. How well do your NN do on points in the range of $x$ where you trained the model? How about points outside the original training data set?
# Summarize what you have learned about the relationship between model complexity (number of parameters), goodness of fit on training data, and the ability to predict well.

# %% [markdown]
# ### Results
# We immediately see that, while fitting the function in the interval $[-1, 1]$ is easily doable, the real challenge consists in obtaining a decent fit outside that interval. The most effective step by far in this regard was found to be changing the activation function to softplus. Using relu or tanh leads to a flat function outside $[-1, 1]$, which is not ideal, while using softplus leads to having straight lines, which follow the function somewhat better. As a loss function we  used mse, to give greater weight to the variations near 1 and -1. We find that a little noise ($\sigma=0.3$) helps, or at least is not detrimental, and seems to be beneficial in preventing overfitting. We ended up with 3 layers with 10 neurons each and a final layer with 1 neuron.

# %%
# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1., 1., 10000)
x_valid = np.random.uniform(-2, 2, 1000)
x_valid.sort()
y_target = 4 - 3 * x_valid - 2 * x_valid**2 + 3 * x_valid**3  # ideal (target) linear function

sigma = 0.3 # noise standard deviation
y_train = np.random.normal(4 - 3 * x_train - 2 * x_train**2 + 3 * x_train**3, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(4 - 3 * x_valid - 2 * x_valid**2 + 3 * x_valid**3, sigma)

# generate comparison inputs
x_in = np.random.uniform(-1, 1, 1000)
x_in.sort()
y_in = 4 - 3 * x_in - 2 * x_in**2 + 3 * x_in**3  # ideal (target) linear function

# plot validation and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target, label='target')
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
newmod = tf.keras.Sequential()
newmod.add(Dense(10, activation='softplus', input_shape=(1,)))   
newmod.add(Dense(10))
newmod.add(Dense(10))
newmod.add(Dense(1))

# compile the model choosing optimizer, loss and metrics objects
newmod.compile(optimizer='sgd', loss='mse', metrics=['mse'])
# get a summary of our composed model
newmod.summary()

bsize = 32

history = newmod.fit(x=x_train, y=y_train, 
          batch_size=bsize, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Model: "sequential_65"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_232 (Dense)           (None, 10)                20
#
#  dense_233 (Dense)           (None, 10)                110
#
#  dense_234 (Dense)           (None, 10)                110
#
#  dense_235 (Dense)           (None, 1)                 11
#
# ...
# Total params: 251
# Trainable params: 251
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 313/313 [==============================] - 0s 794us/step - loss: 0.7609 - mse: 0.7609 - val_loss: 62.4185 - val_mse: 62.4185
# Epoch 2/100
# 313/313 [==============================] - 0s 584us/step - loss: 0.6704 - mse: 0.6704 - val_loss: 62.1422 - val_mse: 62.1422
# Epoch 3/100
# 313/313 [==============================] - 0s 599us/step - loss: 0.6149 - mse: 0.6149 - val_loss: 58.0187 - val_mse: 58.0187
# Epoch 4/100
# ...

# %%
# evaluate mode inside [-1,1]
nscore = newmod.evaluate(x_in, y_in, batch_size=bsize, verbose=0)
# print performance
print('Evaluating model inside [-1,1]')
print('Test loss:', nscore[0])
print('Test accuracy:', nscore[1])

# evaluate model in inside [-2,2]
nscore = newmod.evaluate(x_valid, y_target, batch_size=bsize, verbose=0)
# print performance
print('Evaluating model inside [-2,2]')
print('Test loss:', nscore[0])
print('Test accuracy:', nscore[1])
# Out:
# Evaluating model inside [-1,1]
# Test loss: 0.004193929489701986
# Test accuracy: 0.004193929489701986
# Evaluating model inside [-2,2]
# Test loss: 14.07475757598877
# Test accuracy: 14.07475757598877

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = newmod.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_in, y_in)
plt.grid(True)
plt.show()

x_predicted = np.random.uniform(-2, 2, 100)
y_predicted = newmod.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()
# Out:
# ...
# 4/4 [==============================] - 0s 770us/step

# %% [markdown]
# ### Exercise 11.3
#
# Try to extend the model to fit a simple trigonometric 2D function such as $f(x,y) = \sin(x^2+y^2)$ in the range $x \in [-3/2,3/2]$ and $y \in [-3/2,3/2]$.

# %% [markdown]
# Ideas to meditate on these exercises and judge your results can be found <a href=https://xkcd.com/2048/>here</a>

# %% [markdown]
# ### Results
# Having a good amount of training data is key for this exercise. A good amount of complexity also seems to help.

# %%
from mpl_toolkits.mplot3d import Axes3D


# generate training inputs

# Define the function f(x, y)
def f(x, y):
    return np.sin(x ** 2 + y ** 2)

np.random.seed(0)
x_train = np.random.uniform(-3/2, 3/2, 20000)
x_valid = np.random.uniform(-3/2, 3/2, 6400)
x_valid.sort()
y_train = np.random.uniform(-3/2, 3/2, 20000)
y_valid = np.random.uniform(-3/2, 3/2, 6400)
y_valid.sort()
f_target = f(x_valid, y_valid)  # ideal (target) linear function

sigma = 0.  # noise standard deviation
f_train = np.random.normal(f(x_train, y_train), sigma)  # actual measures from which we want to guess regression parameters
f_valid = np.random.normal(f(x_valid, y_valid), sigma)

# %%
newmod = tf.keras.Sequential()
newmod.add(Dense(64, activation='relu', input_shape=(2,)))   #Relu was chosen as the activation function
newmod.add(Dense(32, activation='relu'))
newmod.add(Dense(32, activation='relu'))
newmod.add(Dense(16, activation='relu'))
newmod.add(Dense(1))

# compile the model choosing optimizer, loss and metrics objects
newmod.compile(optimizer='sgd', loss='mse', metrics=['mse'])
# get a summary of our composed model
newmod.summary()

bsize = 32

history = newmod.fit(x=np.column_stack((x_train, y_train)), y=f_train, 
          batch_size=bsize, epochs=30,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(np.column_stack((x_valid, y_valid)), f_valid))
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_69 (Dense)            (None, 64)                192
#
#  dense_70 (Dense)            (None, 32)                2080
#
#  dense_71 (Dense)            (None, 32)                1056
#
#  dense_72 (Dense)            (None, 16)                528
#
#  dense_73 (Dense)            (None, 1)                 17
#
# ...
# Total params: 3,873
# Trainable params: 3,873
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 625/625 [==============================] - 1s 1ms/step - loss: 0.1507 - mse: 0.1507 - val_loss: 0.3162 - val_mse: 0.3162
# Epoch 2/30
# 625/625 [==============================] - 1s 976us/step - loss: 0.1249 - mse: 0.1249 - val_loss: 0.2731 - val_mse: 0.2731
# Epoch 3/30
# ...

# %%
# evaluate model
nscore = newmod.evaluate(np.column_stack((x_valid, y_valid)), f_valid, batch_size=bsize, verbose=0)
# print performance
print('Evaluating model')
print('Test loss:', nscore[0])
print('Test accuracy:', nscore[1])
# Out:
# Evaluating model
# Test loss: 0.0001936363405548036
# Test accuracy: 0.0001936363405548036

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
# Generate grid points to evaluate the function over the given range
x = np.linspace(-1.5, 1.5, 100)
y = np.linspace(-1.5, 1.5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(x**2 + y**2)

# Flatten the grid points for prediction
x_flat = x.flatten()
y_flat = y.flatten()

# Predict the function values using the trained model
z_pred = newmod.predict(np.column_stack((x_flat, y_flat)))
z_pred = z_pred.reshape(x.shape)

# Plot the target function
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='viridis', edgecolor='none', alpha=0.8)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Target Function')
plt.show()

# Scatter plot of predicted points with color mapping
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(x_flat, y_flat, z_pred, c=z_pred, cmap='viridis', alpha= 0.2)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Predicted Function')

# Add a colorbar to the plot
cbar = fig.colorbar(sc)
cbar.set_label('Predicted z')

plt.show()
# Out:
# 313/313 [==============================] - 0s 557us/step
